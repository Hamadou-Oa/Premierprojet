# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamadou-Oa/Premierprojet/blob/main/Cr%C3%A9ez_mon_premier_data_frame_avec_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Création de mon premier data frame avec pandas

# %%
import pandas as pd
data_csv = pd.read_csv("clients.csv")
data_csv
# Out:
#      identifiant                            email                nom genre
# 0              0        LaurentDagenais@rhyta.com   Laurent Dagenais     M
# 1              1            GuyMarois@fleckens.hu         Guy Marois     M
# 2              2        BeaufortLesage@einrot.com    Beaufort Lesage     M
# 3              3        RussellDurand@armyspy.com     Russell Durand     M
# 4              4             AlexisRiel@rhyta.com        Alexis Riel     M
# ..           ...                              ...                ...   ...
# 223          223  ClaudeDandonneau@jourrapide.com  Claude Dandonneau     F
# 224          224    ApollineMichaud@superrito.com   Apolline Michaud     F
# 225          225       PascalineBeaudry@rhyta.com  Pascaline Beaudry     F
# 226          226     FleurCaouette@jourrapide.com     Fleur Caouette     F
# 227          227      FrancisMasse@jourrapide.com      Francis Masse     M
#
# [228 rows x 4 columns]

# %% [markdown]
# le test avec le fichier json

# %%
import pandas as pd
data_json = pd.read_json("clients.json")
data_json
# Out:
#      identifiant                            email                nom genre
# 0              0        LaurentDagenais@rhyta.com   Laurent Dagenais     M
# 1              1            GuyMarois@fleckens.hu         Guy Marois     M
# 2              2        BeaufortLesage@einrot.com    Beaufort Lesage     M
# 3              3        RussellDurand@armyspy.com     Russell Durand     M
# 4              4             AlexisRiel@rhyta.com        Alexis Riel     M
# ..           ...                              ...                ...   ...
# 223          223  ClaudeDandonneau@jourrapide.com  Claude Dandonneau     F
# 224          224    ApollineMichaud@superrito.com   Apolline Michaud     F
# 225          225       PascalineBeaudry@rhyta.com  Pascaline Beaudry     F
# 226          226     FleurCaouette@jourrapide.com     Fleur Caouette     F
# 227          227      FrancisMasse@jourrapide.com      Francis Masse     M
#
# [228 rows x 4 columns]

# %% [markdown]
# le test avec le fichier xlsx

# %%
import pandas as pd
data_xlsx = pd.read_excel("clients.xlsx")
data_xlsx
# Out:
#      identifiant                            email                nom genre
# 0              0        LaurentDagenais@rhyta.com   Laurent Dagenais     M
# 1              1            GuyMarois@fleckens.hu         Guy Marois     M
# 2              2        BeaufortLesage@einrot.com    Beaufort Lesage     M
# 3              3        RussellDurand@armyspy.com     Russell Durand     M
# 4              4             AlexisRiel@rhyta.com        Alexis Riel     M
# ..           ...                              ...                ...   ...
# 223          223  ClaudeDandonneau@jourrapide.com  Claude Dandonneau     F
# 224          224    ApollineMichaud@superrito.com   Apolline Michaud     F
# 225          225       PascalineBeaudry@rhyta.com  Pascaline Beaudry     F
# 226          226     FleurCaouette@jourrapide.com     Fleur Caouette     F
# 227          227      FrancisMasse@jourrapide.com      Francis Masse     M
#
# [228 rows x 4 columns]

# %%
data_xlsx.head()
# Out:
#    identifiant                      email               nom genre
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3            3  RussellDurand@armyspy.com    Russell Durand     M
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M

# %%
data_json.tail()
# Out:
#      identifiant                            email                nom genre
# 223          223  ClaudeDandonneau@jourrapide.com  Claude Dandonneau     F
# 224          224    ApollineMichaud@superrito.com   Apolline Michaud     F
# 225          225       PascalineBeaudry@rhyta.com  Pascaline Beaudry     F
# 226          226     FleurCaouette@jourrapide.com     Fleur Caouette     F
# 227          227      FrancisMasse@jourrapide.com      Francis Masse     M

# %%
import pandas as pd
dim = data_csv.shape
dim = data_json.shape
dim = data_xlsx.shape
print(data_json.iloc[0])
print(data_xlsx.iloc[1])
print(data_csv.iloc[0])
# Out:
# identifiant                            0
# email          LaurentDagenais@rhyta.com
# nom                     Laurent Dagenais
# genre                                  M
# Name: 0, dtype: object
# identifiant                        1
# email          GuyMarois@fleckens.hu
# nom                       Guy Marois
# genre                              M
# Name: 1, dtype: object
# identifiant                            0
# email          LaurentDagenais@rhyta.com
# nom                     Laurent Dagenais
# genre                                  M
# Name: 0, dtype: object

# %% [markdown]
# Caractéristiques globales du data frame

# %% [markdown]
# Le type

# %%
data_csv.dtypes
data_json.dtypes
data_xlsx.dtypes
# Out:
# identifiant     int64
# email          object
# nom            object
# genre          object
# dtype: object
